# %% [markdown]
# # Spherical Fourier Neural Operators
#
# A simple notebook to showcase spherical Fourier Neural Operators

# %% [markdown]
# ## Preparation

# %%
import paddle
import paddle.nn as nn
from paddle.io import DataLoader
from paddle import amp
from paddle.optimizer.lr import OneCycleLR
import sys
sys.path.append("../")
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

from math import ceil, sqrt

import time

cmap='twilight_shifted'

# %%
enable_amp = False

# set device
device = paddle.CUDAPlace(0) if paddle.device.cuda.device_count() > 0 else paddle.CPUPLace()

# %% [markdown]
# ### Training data
# to train our geometric FNOs, we require training data. To this end let us prepare a Dataloader which computes results on the fly:

# %%
# dataset
from paddle_harmonics.examples.sfno import PdeDataset

# 1 hour prediction steps
dt = 1*3600
dt_solver = 150
nsteps = dt//dt_solver
dataset = PdeDataset(dt=dt, nsteps=nsteps, dims=(256, 512), device=device, normalize=True)
# There is still an issue with parallel dataloading. Do NOT use it at the moment
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, num_workers=0, persistent_workers=False)
solver = dataset.solver.to(device)

nlat = dataset.nlat
nlon = dataset.nlon
# Out:
# W1106 16:18:00.069643 70677 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.3, Runtime API Version: 12.4
# W1106 16:18:00.071056 70677 gpu_resources.cc:164] device: 0, cuDNN Version: 9.4.
# W1106 16:18:01.961211 70677 multiply_fwd_func.cc:76] got different data type, run type promotion automatically, this may cause data type been changed.
# W1106 16:18:01.966238 70677 dygraph_functions.cc:83993] got different data type, run type promotion automatically, this may cause data type been changed.

# %%
paddle.seed(0)
inp, tar = dataset[0]

fig = plt.figure()
im = solver.plot_griddata(inp[2], fig, vmax=3, vmin=-3)
plt.title("input")
plt.colorbar(im)
plt.show()

fig = plt.figure()
im = solver.plot_griddata(tar[2], fig, vmax=3, vmin=-3)
plt.title("target")
plt.colorbar(im)
plt.show()

# %% [markdown]
# ### Defining the geometric Fourier Neural Operator

# %%
from paddle_harmonics.examples.sfno import SphericalFourierNeuralOperatorNet as SFNO

# %%
model = SFNO(spectral_transform='sht', operator_type='driscoll-healy', img_size=(nlat, nlon), grid="equiangular",
                 num_layers=4, scale_factor=3, embed_dim=16, big_skip=True, pos_embed="lat", use_mlp=False, normalization_layer="none").to(device)

# %%
# pointwise model for sanity checking
# class MLP(nn.Module):
#     def __init__(self,
#                  input_dim = 3,
#                  output_dim = 3,
#                  num_layers = 2,
#                  hidden_dim = 32,
#                  activation_function = nn.ReLU,
#                  bias = False):
#         super().__init__()
    
#         current_dim = input_dim
#         layers = []
#         for l in range(num_layers-1):
#             fc = nn.Conv2d(current_dim, hidden_dim, 1, bias=True)
#             # initialize the weights correctly
#             scale = sqrt(2. / current_dim)
#             nn.init.normal_(fc.weight, mean=0., std=scale)
#             if fc.bias is not None:
#                 nn.init.constant_(fc.bias, 0.0)
#             layers.append(fc)
#             layers.append(activation_function())
#             current_dim = hidden_dim
#         fc = nn.Conv2d(current_dim, output_dim, 1, bias=False)
#         scale = sqrt(1. / current_dim)
#         nn.init.normal_(fc.weight, mean=0., std=scale)
#         if fc.bias is not None:
#             nn.init.constant_(fc.bias, 0.0)
#         layers.append(fc)
#         self.mlp = nn.Sequential(*layers)

#     def forward(self, x):
#         return self.mlp(x)

# model = MLP(num_layers=10).to(device)

# %% [markdown]
# ## Training the model

# %%
def l2loss_sphere(solver, prd, tar, relative=False, squared=True):
    loss = solver.integrate_grid((prd - tar)**2, dimensionless=True).sum(axis=-1)
    if relative:
        loss = loss / solver.integrate_grid(tar**2, dimensionless=True).sum(axis=-1)
    
    if not squared:
        loss = paddle.sqrt(loss)
    loss = loss.mean()

    return loss

def spectral_l2loss_sphere(solver, prd, tar, relative=False, squared=True):
    # compute coefficients
    coeffs = paddle.as_real(solver.sht(prd - tar))
    coeffs = coeffs[..., 0]**2 + coeffs[..., 1]**2
    norm2 = coeffs[..., :, 0] + 2 * paddle.sum(coeffs[..., :, 1:], axis=-1)
    loss = paddle.sum(norm2, axis=(-1,-2))

    if relative:
        tar_coeffs = paddle.as_real(solver.sht(tar))
        tar_coeffs = tar_coeffs[..., 0]**2 + tar_coeffs[..., 1]**2
        tar_norm2 = tar_coeffs[..., :, 0] + 2 * paddle.sum(tar_coeffs[..., :, 1:], axis=-1)
        tar_norm2 = paddle.sum(tar_norm2, axis=(-1,-2))
        loss = loss / tar_norm2

    if not squared:
        loss = paddle.sqrt(loss)
    loss = loss.mean()

    return loss

# %%
# training function
def train_model(model, dataloader, optimizer, scheduler=None, nepochs=20, nfuture=0, num_examples=256, num_valid=8, loss_fn='l2'):

    train_start = time.time()

    for epoch in range(nepochs):

        # time each epoch
        epoch_start = time.time()

        dataloader.dataset.set_initial_condition('random')
        dataloader.dataset.set_num_examples(num_examples)

        optimizer.clear_grad()

        # do the training
        acc_loss = 0
        model.train()
        for inp, tar in dataloader:
            with amp.auto_cast(enable=enable_amp):
                prd = model(inp)
                for _ in range(nfuture):
                    prd = model(prd)
                if loss_fn == 'l2':
                    loss = l2loss_sphere(solver, prd, tar)
                elif loss_fn == "spectral l2":
                    loss = spectral_l2loss_sphere(solver, prd, tar)

            acc_loss += loss.item() * inp.shape[0]

            optimizer.clear_grad()
            # gscaler.scale(loss).backward()
            loss.backward()
            optimizer.step()
            # gscaler.update()

        if scheduler is not None:
            scheduler.step()

        acc_loss = acc_loss / len(dataloader.dataset)

        dataloader.dataset.set_initial_condition('random')
        dataloader.dataset.set_num_examples(num_valid)

        # perform validation
        valid_loss = 0
        model.eval()
        with paddle.no_grad():
            for inp, tar in dataloader:
                prd = model(inp)
                for _ in range(nfuture):
                    prd = model(prd)
                loss = l2loss_sphere(solver, prd, tar, relative=True)

                valid_loss += loss.item() * inp.shape[0]

        valid_loss = valid_loss / len(dataloader.dataset)

        epoch_time = time.time() - epoch_start

        print(f'--------------------------------------------------------------------------------')
        print(f'Epoch {epoch} summary:')
        print(f'time taken: {epoch_time}')
        print(f'accumulated training loss: {acc_loss}')
        print(f'relative validation loss: {valid_loss}')

    train_time = time.time() - train_start

    print(f'--------------------------------------------------------------------------------')
    print(f'done. Training took {train_time}.')
    return valid_loss

# %%
# set seed
paddle.seed(333)

optimizer = paddle.optimizer.Adam(parameters=model.parameters(), learning_rate=3E-3, weight_decay=0.0)
gscaler = amp.GradScaler(enable=enable_amp)
train_model(model, dataloader, optimizer, nepochs=10)

# multistep training
# learning_rate = 5e-4
# optimizer = paddle.optim.Adam(fno_model.parameters(), lr=learning_rate)
# dataloader.dataset.nsteps = 2 * dt//dt_solver
# train_model(fno_model, dataloader, optimizer, nepochs=10, nfuture=1)
# dataloader.dataset.nsteps = 1 * dt//dt_solver
# Out:
# --------------------------------------------------------------------------------
# Epoch 0 summary:
# time taken: 202.05663681030273
# accumulated training loss: 226.9325623512268
# relative validation loss: 0.40360602736473083
# --------------------------------------------------------------------------------
# Epoch 1 summary:
# time taken: 195.86467003822327
# accumulated training loss: 14.938525304198265
# relative validation loss: 0.2364514395594597
# --------------------------------------------------------------------------------
# Epoch 2 summary:
# time taken: 172.929274559021
# accumulated training loss: 9.760927647352219
# relative validation loss: 0.16558771580457687
# --------------------------------------------------------------------------------
# Epoch 3 summary:
# time taken: 219.263601064682
# accumulated training loss: 7.046890251338482
# relative validation loss: 0.12382937967777252
# --------------------------------------------------------------------------------
# Epoch 4 summary:
# time taken: 764.7056841850281
# accumulated training loss: 5.366650454699993
# relative validation loss: 0.09601996839046478
# --------------------------------------------------------------------------------
# Epoch 5 summary:
# time taken: 783.731404542923
# accumulated training loss: 4.237471126019955
# relative validation loss: 0.07661208882927895
# --------------------------------------------------------------------------------
# Epoch 6 summary:
# time taken: 714.4589712619781
# accumulated training loss: 3.402406968176365
# relative validation loss: 0.06227022036910057
# --------------------------------------------------------------------------------
# Epoch 7 summary:
# time taken: 733.2898373603821
# accumulated training loss: 2.7659731060266495
# relative validation loss: 0.0507119745016098
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 6
#       4 optimizer = paddle.optimizer.Adam(parameters=model.parameters(), learning_rate=3E-3, weight_decay=0.0)
#       5 gscaler = amp.GradScaler(enable=enable_amp)
# ----> 6 train_model(model, dataloader, optimizer, nepochs=10)
#       8 # multistep training
#       9 # learning_rate = 5e-4
#      10 # optimizer = paddle.optim.Adam(fno_model.parameters(), lr=learning_rate)
#      11 # dataloader.dataset.nsteps = 2 * dt//dt_solver
#      12 # train_model(fno_model, dataloader, optimizer, nepochs=10, nfuture=1)
#      13 # dataloader.dataset.nsteps = 1 * dt//dt_solver
#
# Cell In[21], line 19, in train_model(model, dataloader, optimizer, scheduler, nepochs, nfuture, num_examples, num_valid, loss_fn)
#      17 acc_loss = 0
#      18 model.train()
# ---> 19 for inp, tar in dataloader:
#      20     with amp.auto_cast(enable=enable_amp):
#      21         prd = model(inp)
#
# File /opt/miniforge3/envs/py310/lib/python3.10/site-packages/paddle/io/dataloader/dataloader_iter.py:301, in _DataLoaderIterSingleProcess.__next__(self)
#     298 benchmark().before_reader()
#     299 if in_dynamic_mode():
#     300     data = core.eager.read_next_tensor_list(
# --> 301         self._reader.read_next_list()[0]
#     302     )
#     303     data = _restore_batch(data, self._structure_infos.pop(0))
#     304 else:
#     305     # in static graph mode
#
# KeyboardInterrupt:

# %%
dataloader.dataset.set_initial_condition('random')

paddle.seed(0)

with paddle.no_grad():
    inp, tar = next(iter(dataloader))
    out = model(inp).detach()

s = 0; ch = 2

fig = plt.figure()
im = solver.plot_griddata(inp[s, ch], fig, projection='3d', title='input')
plt.colorbar(im)
plt.show()

fig = plt.figure()
im = solver.plot_griddata(out[s, ch], fig, projection='3d', title='prediction')
plt.colorbar(im)
plt.show()

fig = plt.figure()
im = solver.plot_griddata(tar[s, ch], fig, projection='3d', title='target')
plt.colorbar(im)
plt.show()

fig = plt.figure()
im = solver.plot_griddata((tar-out)[s, ch], fig, projection='3d', title='error')
plt.colorbar(im)
plt.show()
