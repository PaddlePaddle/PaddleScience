# %% [markdown]
# # Differentiable Shallow Water Equations
#
# We present a differentiable SWE solver, based on `paddle-harmonics`.

# %%
import paddle
import paddle.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

from math import ceil, floor

import sys
sys.path.append("../")
from paddle_harmonics.sht import *
from paddle_harmonics.examples import ShallowWaterSolver

# %%
device = paddle.CUDAPlace(0) if paddle.device.cuda.device_count() > 0 else paddle.CPUPLace()

# %% [markdown]
# We define a shallow water solver class in `shallow_water_equations.py`

# %%
# initialize parameters:
nlat = 512
nlon = 2*nlat
lmax = ceil(128)
mmax = lmax
# timestepping
dt = 75
maxiter = 12*int(86400/dt)

# initialize solver class
swe_solver = ShallowWaterSolver(nlat, nlon, dt, lmax=lmax, mmax=mmax).to(device)

lons = swe_solver.lons
lats = swe_solver.lats

jj, ii = paddle.triu_indices(lmax, mmax)
# Out:
# W1106 17:43:53.772507 144004 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.5, Driver API Version: 12.3, Runtime API Version: 12.4
# W1106 17:43:53.774278 144004 gpu_resources.cc:164] device: 0, cuDNN Version: 9.4.

# %%
uspec0 = swe_solver.galewsky_initial_condition()
# Out:
# W1106 17:43:55.331231 144004 dygraph_functions.cc:88576] got different data type, run type promotion automatically, this may cause data type been changed.
# W1106 17:43:55.332129 144004 multiply_fwd_func.cc:76] got different data type, run type promotion automatically, this may cause data type been changed.
# W1106 17:43:55.332373 144004 dygraph_functions.cc:86562] got different data type, run type promotion automatically, this may cause data type been changed.
# W1106 17:43:55.360435 144004 dygraph_functions.cc:85972] got different data type, run type promotion automatically, this may cause data type been changed.
# W1106 17:43:55.399171 144004 dygraph_functions.cc:81398] got different data type, run type promotion automatically, this may cause data type been changed.

# %% [markdown]
# We are now ready to run the simulation. To perform integration in time, we will use third-order Adams-Bashforth. As we are currently not interested in gradients, we can wrap the function in `paddle.no_grad()`.

# %%
dudtspec = paddle.zeros([3, 3, swe_solver.lmax, swe_solver.mmax], dtype=paddle.complex128)
inew = 0
inow = 1
iold = 2

uspec = uspec0.clone().to(device)

# save for later:
nskip = 50
utspec = paddle.zeros([floor(maxiter//nskip) + 1, *uspec.shape]).astype("complex128").to(device)

with paddle.no_grad():
    for iter in range(maxiter+1):
        t = iter*dt

        if iter % nskip == 0:
            utspec[iter//nskip] = uspec
            print(f"t={t/3600:.2f} hours")

        dudtspec[inew] = swe_solver.dudtspec(uspec)
        
        # update vort,div,phiv with third-order adams-bashforth.
        # forward euler, then 2nd-order adams-bashforth time steps to start.
        if iter == 0:
            dudtspec[inow] = dudtspec[inew]
            dudtspec[iold] = dudtspec[inew]
        elif iter == 1:
            dudtspec[iold] = dudtspec[inew]

        uspec = uspec + swe_solver.dt*( (23./12.) * dudtspec[inew] - (16./12.) * dudtspec[inow] + (5./12.) * dudtspec[iold] )

        # implicit hyperdiffusion for vort and div.
        uspec[1:] = swe_solver.hyperdiff * uspec[1:]
        # cycle through the indices
        inew = (inew - 1) % 3
        inow = (inow - 1) % 3
        iold = (iold - 1) % 3
# Out:
# t=0.00 hours
# W1106 17:43:55.701275 144004 dygraph_functions.cc:83993] got different data type, run type promotion automatically, this may cause data type been changed.
# t=1.04 hours
# t=2.08 hours
# t=3.12 hours
# t=4.17 hours
# t=5.21 hours
# t=6.25 hours
# t=7.29 hours
# t=8.33 hours
# t=9.38 hours
# t=10.42 hours
# t=11.46 hours
# t=12.50 hours
# t=13.54 hours
# t=14.58 hours
# t=15.62 hours
# t=16.67 hours
# t=17.71 hours
# t=18.75 hours
# t=19.79 hours
# t=20.83 hours
# t=21.88 hours
# t=22.92 hours
# t=23.96 hours
# t=25.00 hours
# t=26.04 hours
# t=27.08 hours
# t=28.12 hours
# t=29.17 hours
# t=30.21 hours
# t=31.25 hours
# t=32.29 hours
# t=33.33 hours
# t=34.38 hours
# t=35.42 hours
# t=36.46 hours
# t=37.50 hours
# t=38.54 hours
# t=39.58 hours
# t=40.62 hours
# t=41.67 hours
# t=42.71 hours
# t=43.75 hours
# t=44.79 hours
# t=45.83 hours
# t=46.88 hours
# t=47.92 hours
# t=48.96 hours
# t=50.00 hours
# t=51.04 hours
# t=52.08 hours
# t=53.12 hours
# t=54.17 hours
# t=55.21 hours
# t=56.25 hours
# t=57.29 hours
# t=58.33 hours
# t=59.38 hours
# t=60.42 hours
# t=61.46 hours
# t=62.50 hours
# t=63.54 hours
# t=64.58 hours
# t=65.62 hours
# t=66.67 hours
# t=67.71 hours
# t=68.75 hours
# t=69.79 hours
# t=70.83 hours
# t=71.88 hours
# t=72.92 hours
# t=73.96 hours
# t=75.00 hours
# t=76.04 hours
# t=77.08 hours
# t=78.12 hours
# t=79.17 hours
# t=80.21 hours
# t=81.25 hours
# t=82.29 hours
# t=83.33 hours
# t=84.38 hours
# t=85.42 hours
# t=86.46 hours
# t=87.50 hours
# t=88.54 hours
# t=89.58 hours
# t=90.62 hours
# t=91.67 hours
# t=92.71 hours
# t=93.75 hours
# t=94.79 hours
# t=95.83 hours
# t=96.88 hours
# t=97.92 hours
# t=98.96 hours
# t=100.00 hours
# t=101.04 hours
# t=102.08 hours
# t=103.12 hours
# t=104.17 hours
# t=105.21 hours
# t=106.25 hours
# t=107.29 hours
# t=108.33 hours
# t=109.38 hours
# t=110.42 hours
# t=111.46 hours
# t=112.50 hours
# t=113.54 hours
# t=114.58 hours
# t=115.62 hours
# t=116.67 hours
# t=117.71 hours
# t=118.75 hours
# t=119.79 hours
# t=120.83 hours
# t=121.88 hours
# t=122.92 hours
# t=123.96 hours
# t=125.00 hours
# t=126.04 hours
# t=127.08 hours
# t=128.12 hours
# t=129.17 hours
# t=130.21 hours
# t=131.25 hours
# t=132.29 hours
# t=133.33 hours
# t=134.38 hours
# t=135.42 hours
# t=136.46 hours
# t=137.50 hours
# t=138.54 hours
# t=139.58 hours
# t=140.62 hours
# t=141.67 hours
# t=142.71 hours
# t=143.75 hours
# t=144.79 hours
# t=145.83 hours
# t=146.88 hours
# t=147.92 hours
# t=148.96 hours
# t=150.00 hours
# t=151.04 hours
# t=152.08 hours
# t=153.12 hours
# t=154.17 hours
# t=155.21 hours
# t=156.25 hours
# t=157.29 hours
# t=158.33 hours
# t=159.38 hours
# t=160.42 hours
# t=161.46 hours
# t=162.50 hours
# t=163.54 hours
# t=164.58 hours
# t=165.62 hours
# t=166.67 hours
# t=167.71 hours
# t=168.75 hours
# t=169.79 hours
# t=170.83 hours
# t=171.88 hours
# t=172.92 hours
# t=173.96 hours
# t=175.00 hours
# t=176.04 hours
# t=177.08 hours
# t=178.12 hours
# t=179.17 hours
# t=180.21 hours
# t=181.25 hours
# t=182.29 hours
# t=183.33 hours
# t=184.38 hours
# t=185.42 hours
# t=186.46 hours
# t=187.50 hours
# t=188.54 hours
# t=189.58 hours
# t=190.62 hours
# t=191.67 hours
# t=192.71 hours
# t=193.75 hours
# t=194.79 hours
# t=195.83 hours
# t=196.88 hours
# t=197.92 hours
# t=198.96 hours
# t=200.00 hours
# t=201.04 hours
# t=202.08 hours
# t=203.12 hours
# t=204.17 hours
# t=205.21 hours
# t=206.25 hours
# t=207.29 hours
# t=208.33 hours
# t=209.38 hours
# t=210.42 hours
# t=211.46 hours
# t=212.50 hours
# t=213.54 hours
# t=214.58 hours
# t=215.62 hours
# t=216.67 hours
# t=217.71 hours
# t=218.75 hours
# t=219.79 hours
# t=220.83 hours
# t=221.88 hours
# t=222.92 hours
# t=223.96 hours
# t=225.00 hours
# t=226.04 hours
# t=227.08 hours
# t=228.12 hours
# t=229.17 hours
# t=230.21 hours
# t=231.25 hours
# t=232.29 hours
# t=233.33 hours
# t=234.38 hours
# t=235.42 hours
# t=236.46 hours
# t=237.50 hours
# t=238.54 hours
# t=239.58 hours
# t=240.62 hours
# t=241.67 hours
# t=242.71 hours
# t=243.75 hours
# t=244.79 hours
# t=245.83 hours
# t=246.88 hours
# t=247.92 hours
# t=248.96 hours
# t=250.00 hours
# t=251.04 hours
# t=252.08 hours
# t=253.12 hours
# t=254.17 hours
# t=255.21 hours
# t=256.25 hours
# t=257.29 hours
# t=258.33 hours
# t=259.38 hours
# t=260.42 hours
# t=261.46 hours
# t=262.50 hours
# t=263.54 hours
# t=264.58 hours
# t=265.62 hours
# t=266.67 hours
# t=267.71 hours
# t=268.75 hours
# t=269.79 hours
# t=270.83 hours
# t=271.88 hours
# t=272.92 hours
# t=273.96 hours
# t=275.00 hours
# t=276.04 hours
# t=277.08 hours
# t=278.12 hours
# t=279.17 hours
# t=280.21 hours
# t=281.25 hours
# t=282.29 hours
# t=283.33 hours
# t=284.38 hours
# t=285.42 hours
# t=286.46 hours
# t=287.50 hours

# %%
fig = plt.figure()
im = swe_solver.plot_specdata(uspec[1], fig, cmap="twilight_shifted")
plt.show()

# %% [markdown]
# ### Plotting a video
#
# let us plot the vorticity for our rollout:

# %%
# prepare figure for animation
fig = plt.figure(figsize=(8, 6), dpi=72)
moviewriter = animation.writers['pillow'](fps=20)
moviewriter.setup(fig, './plots/zonal_jet.gif', dpi=72)

plot_pvrt = False

for i in range(utspec.shape[0]):
    t = i*nskip*dt

    if plot_pvrt:
        variable = swe_solver.potential_vorticity(utspec[i])
    else:
        variable = swe_solver.spec2grid(utspec[i, 1])

    plt.clf()
    # swe_solver.plot_griddata(variable, cmap=cmap, vmin=-0.2, vmax=1.8, title=f'zonal jet t={t/3600:.2f} hours')
    swe_solver.plot_griddata(variable, fig, cmap="twilight_shifted", antialiased=False)
    plt.draw()
    moviewriter.grab_frame()


moviewriter.finish()

# %% [markdown]
# ## Conservation of potential vorticity

# %%
pvrttspec = paddle.zeros([floor(maxiter//nskip) + 1, lmax, mmax]).astype("complex128").to(device)
for i in range(utspec.shape[0]):
    pvrttspec[i] = swe_solver.grid2spec(swe_solver.potential_vorticity(utspec[i]))

# %%
total_vrt = pvrttspec.abs()**2
# total_vrt = utspec[..., 1, :, :].abs()**2
total_vrt = paddle.sqrt(paddle.sum(total_vrt[..., :1], axis=(-1, -2)) + paddle.sum(2 * total_vrt[..., 1:], axis=(-1, -2))).cpu()
t = nskip*dt * paddle.arange(utspec.shape[0])

plt.plot(t.numpy(), (total_vrt / total_vrt[0]).numpy(), label='Spectral Solver')
plt.title('Total vorticity over time')
plt.ylim((0,1))
plt.legend(loc='lower left')
